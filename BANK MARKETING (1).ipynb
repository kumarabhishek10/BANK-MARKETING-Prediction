# %%
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing Data set

# %%
df_test=pd.read_csv('termdeposit_test.csv')
df_train=pd.read_csv('termdeposit_train.csv')

# %%
df_test
# Out:
#           ID  age            job   marital  education default  balance  \
# 0      38441   32       services   married  secondary      no      118
# 1      40403   78        retired  divorced    primary      no     2787
# 2       3709   31  self-employed    single   tertiary      no      144
# 3      37422   57       services    single    primary      no     3777
# 4      12527   45    blue-collar  divorced  secondary      no     -705
# ...      ...  ...            ...       ...        ...     ...      ...
# 13559  23465   39     management   married   tertiary      no       45
# 13560  11743   54    blue-collar   married    primary      no     2281
# 13561  28292   35        retired   married    primary      no      285
# 13562  45163   29         admin.    single  secondary      no      464
# 13563  34839   29         admin.   married  secondary      no        2
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
df_train
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 0      26110   56      admin.   married    unknown      no     1933      no
# 1      40576   31     unknown   married  secondary      no        3      no
# 2      15320   27    services   married  secondary      no      891     yes
# 3      43962   57  management  divorced   tertiary      no     3287      no
# 4      29842   31  technician   married  secondary      no      119     yes
# ...      ...  ...         ...       ...        ...     ...      ...     ...
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
# ...

# %%
df_train.head()
# Out:
#       ID  age         job   marital  education default  balance housing loan  \
# 0  26110   56      admin.   married    unknown      no     1933      no   no
# 1  40576   31     unknown   married  secondary      no        3      no   no
# 2  15320   27    services   married  secondary      no      891     yes   no
# 3  43962   57  management  divorced   tertiary      no     3287      no   no
# 4  29842   31  technician   married  secondary      no      119     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   19   nov        44         2     -1         0  unknown
# 1   cellular   20   jul        91         2     -1         0  unknown
# 2   cellular   18   jul       240         1     -1         0  unknown
# 3   cellular   22   jun       867         1     84         3  success
# 4   cellular    4   feb       380         1     -1         0  unknown
#
#   subscribed
# 0         no
# 1         no
# 2         no
# 3        yes
# ...

# %%
df_train.tail()
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
#       loan    contact  day month  duration  campaign  pdays  previous  \
# 31642   no   cellular   12   may       116         2     -1         0
# 31643  yes   cellular    5   jun       438         2     -1         0
# 31644   no   cellular    7   aug        37         3     -1         0
# 31645   no  telephone   15   may        22         7    337        12
# 31646   no   cellular   11   jul      1973         2     -1         0
#
#       poutcome subscribed
# 31642  unknown         no
# 31643  unknown        yes
# ...

# %%
df_test.head()
# Out:
#       ID  age            job   marital  education default  balance housing  \
# 0  38441   32       services   married  secondary      no      118     yes
# 1  40403   78        retired  divorced    primary      no     2787      no
# 2   3709   31  self-employed    single   tertiary      no      144     yes
# 3  37422   57       services    single    primary      no     3777     yes
# 4  12527   45    blue-collar  divorced  secondary      no     -705      no
#
#   loan    contact  day month  duration  campaign  pdays  previous poutcome
# 0   no   cellular   15   may        20         6     -1         0  unknown
# 1   no  telephone    1   jul       372         1     -1         0  unknown
# 2   no    unknown   16   may       676         1     -1         0  unknown
# 3   no  telephone   13   may        65         2     -1         0  unknown
# 4  yes    unknown    3   jul       111         1     -1         0  unknown

# %%
df_test.tail()
# Out:
#           ID  age          job  marital  education default  balance housing  \
# 13559  23465   39   management  married   tertiary      no       45      no
# 13560  11743   54  blue-collar  married    primary      no     2281     yes
# 13561  28292   35      retired  married    primary      no      285     yes
# 13562  45163   29       admin.   single  secondary      no      464      no
# 13563  34839   29       admin.  married  secondary      no        2     yes
#
#       loan   contact  day month  duration  campaign  pdays  previous poutcome
# 13559   no  cellular   28   aug       148         4     -1         0  unknown
# 13560   no   unknown   20   jun       158         1     -1         0  unknown
# 13561   no  cellular   29   jan       136         1     -1         0  unknown
# 13562   no  cellular    9   nov       208         2     91         3  success
# 13563   no  cellular    6   may       339         1    362         1  failure

# %%
#Removing ID column from both the datasets as it has all unique values and is of no significance

# %%
df_train.drop('ID',axis=1,inplace=True)
df_test.drop('ID',axis=1,inplace=True)

# %%
df_train
# Out:
#        age         job   marital  education default  balance housing loan  \
# 0       56      admin.   married    unknown      no     1933      no   no
# 1       31     unknown   married  secondary      no        3      no   no
# 2       27    services   married  secondary      no      891     yes   no
# 3       57  management  divorced   tertiary      no     3287      no   no
# 4       31  technician   married  secondary      no      119     yes   no
# ...    ...         ...       ...        ...     ...      ...     ...  ...
# 31642   29  management    single   tertiary      no        0     yes   no
# 31643   53  management  divorced   tertiary      no      380      no  yes
# 31644   32  management    single   tertiary      no      312      no   no
# 31645   57  technician   married  secondary      no      225     yes   no
# 31646   55  management  divorced  secondary      no      204     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df_test
# Out:
#        age            job   marital  education default  balance housing loan  \
# 0       32       services   married  secondary      no      118     yes   no
# 1       78        retired  divorced    primary      no     2787      no   no
# 2       31  self-employed    single   tertiary      no      144     yes   no
# 3       57       services    single    primary      no     3777     yes   no
# 4       45    blue-collar  divorced  secondary      no     -705      no  yes
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 13559   39     management   married   tertiary      no       45      no   no
# 13560   54    blue-collar   married    primary      no     2281     yes   no
# 13561   35        retired   married    primary      no      285     yes   no
# 13562   29         admin.    single  secondary      no      464      no   no
# 13563   29         admin.   married  secondary      no        2     yes   no
#
# ...

# %%
df_train.shape
# Out:
# (31647, 17)

# %%
df_test.shape
# Out:
# (13564, 16)

# %%
df_train.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'subscribed'],
#       dtype='object')

# %%
df_test.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome'],
#       dtype='object')

# %%
df_train.dtypes
# Out:
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance        int64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# subscribed    object
# dtype: object

# %%
df_train.dtypes
# Out:
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance        int64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# subscribed    object
# dtype: object

# %%
df_train.isnull().sum()
# Out:
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# subscribed    0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         31647 non-null  int64
#  1   job         31647 non-null  object
#  2   marital     31647 non-null  object
#  3   education   31647 non-null  object
#  4   default     31647 non-null  object
#  5   balance     31647 non-null  int64
#  6   housing     31647 non-null  object
#  7   loan        31647 non-null  object
#  8   contact     31647 non-null  object
#  9   day         31647 non-null  int64
#  10  month       31647 non-null  object
#  11  duration    31647 non-null  int64
#  12  campaign    31647 non-null  int64
#  13  pdays       31647 non-null  int64
#  14  previous    31647 non-null  int64
#  15  poutcome    31647 non-null  object
#  16  subscribed  31647 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 4.1+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13564 entries, 0 to 13563
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        13564 non-null  int64
#  1   job        13564 non-null  object
#  2   marital    13564 non-null  object
#  3   education  13564 non-null  object
#  4   default    13564 non-null  object
#  5   balance    13564 non-null  int64
#  6   housing    13564 non-null  object
#  7   loan       13564 non-null  object
#  8   contact    13564 non-null  object
#  9   day        13564 non-null  int64
#  10  month      13564 non-null  object
#  11  duration   13564 non-null  int64
#  12  campaign   13564 non-null  int64
#  13  pdays      13564 non-null  int64
#  14  previous   13564 non-null  int64
#  15  poutcome   13564 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 1.7+ MB

# %%
sns.heatmap(df_train.isnull())   #single colour heatmap as no null values are present
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df_test.isnull())   #single colour heatmap as no null values are present
# Out:
# <AxesSubplot:>

# %%
df_train.nunique()
# Out:
# age             76
# job             12
# marital          3
# education        4
# default          2
# balance       6326
# housing          2
# loan             2
# contact          3
# day             31
# month           12
# duration      1454
# campaign        45
# pdays          509
# previous        38
# poutcome         4
# subscribed       2
# dtype: int64

# %%
df_test.nunique()
# Out:
# age            75
# job            12
# marital         3
# education       4
# default         2
# balance      4292
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration     1201
# campaign       40
# pdays         422
# previous       33
# poutcome        4
# dtype: int64

# %%
#checking the value counts of unique values in each column

for i in df_train.columns:
    print(df_train[i].value_counts())
    print('\n')  #new line
# Out:
# 32    1457
# 31    1417
# 33    1406
# 34    1321
# 35    1314
#       ...
# 92       1
# 95       1
# 93       1
# 94       1
# 90       1
# Name: age, Length: 76, dtype: int64
#
#
# blue-collar      6842
# management       6639
# technician       5307
# admin.           3631
# services         2903
# retired          1574
# self-employed    1123
# entrepreneur     1008
# unemployed        905
# housemaid         874
# student           635
# unknown           206
# Name: job, dtype: int64
#
#
# married     19095
# single       8922
# divorced     3630
# Name: marital, dtype: int64
#
#
# secondary    16224
# tertiary      9301
# primary       4808
# unknown       1314
# Name: education, dtype: int64
#
#
# no     31062
# yes      585
# Name: default, dtype: int64
#
#
#  0        2470
#  1         137
#  2         109
#  4          95
#  3          88
#           ...
#  15120       1
# -713         1
# -905         1
#  4722        1
#  2968        1
# ...

# %%
for i in df_test.columns:
    print(df_test[i].value_counts())
    print('\n')  #new line
# Out:
# 32    628
# 34    609
# 35    580
# 31    579
# 33    566
#      ...
# 95      1
# 86      1
# 92      1
# 89      1
# 90      1
# Name: age, Length: 75, dtype: int64
#
#
# blue-collar      2890
# management       2819
# technician       2290
# admin.           1540
# services         1251
# retired           690
# entrepreneur      479
# self-employed     456
# unemployed        398
# housemaid         366
# student           303
# unknown            82
# Name: job, dtype: int64
#
#
# married     8119
# single      3868
# divorced    1577
# Name: marital, dtype: int64
#
#
# secondary    6978
# tertiary     4000
# primary      2043
# unknown       543
# Name: education, dtype: int64
#
#
# no     13334
# yes      230
# Name: default, dtype: int64
#
#
#  0       1044
#  1         58
#  2         47
#  3         46
#  4         44
#          ...
# -140        1
#  6495       1
#  8180       1
#  3684       1
#  4256       1
# Name: balance, Length: 4292, dtype: int64
#
#
# yes    7546
# ...

# %%
#Seperating Numerical and categorical columns

train_categorical_col=[]
for i in df_train.columns:
    if df_train.dtypes[i]=='object':
        train_categorical_col.append(i)
print("Categorical columns in train data are:", train_categorical_col)
print('\n')

train_numerical_col=[]
for i in df_train.columns:
    if df_train.dtypes[i]!='object':
        train_numerical_col.append(i)
print("Numerical columns in train data are:", train_numerical_col)
print("\n")
# Out:
# Categorical columns in train data are: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'subscribed']
#
#
# Numerical columns in train data are: ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
test_categorical_col=[]
for i in df_test.columns:
    if df_test.dtypes[i]=='object':
        test_categorical_col.append(i)
print("Categorical columns in test data are:", test_categorical_col)
print('\n')

test_numerical_col=[]
for i in df_test.columns:
    if df_test.dtypes[i]!='object':
        test_numerical_col.append(i)
print("Numerical columns in test data are:", test_numerical_col)
print("\n")
# Out:
# Categorical columns in test data are: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome']
#
#
# Numerical columns in test data are: ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
#statistical summary of numerical values

df_train.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  31647.000000   31647.000000  31647.000000  31647.000000  31647.000000
# mean      40.957247    1363.890258     15.835466    258.113534      2.765697
# std       10.625134    3028.304293      8.337097    257.118973      3.113830
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      73.000000      8.000000    104.000000      1.000000
# 50%       39.000000     450.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1431.000000     21.000000    318.500000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  31647.000000  31647.000000
# mean      39.576042      0.574272
# std       99.317592      2.422529
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
#statistical summary of numerical values

df_test.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  13564.000000  13564.000000  13564.000000  13564.000000  13564.000000
# mean      40.887128   1358.496535     15.738646    258.278679      2.759510
# std       10.604108   3082.940623      8.288174    258.488648      3.060928
# min       18.000000  -3313.000000      1.000000      0.000000      1.000000
# 25%       33.000000     71.000000      8.000000    102.000000      1.000000
# 50%       39.000000    445.000000     16.000000    180.000000      2.000000
# 75%       48.000000   1413.250000     21.000000    319.000000      3.000000
# max       95.000000  98417.000000     31.000000   3253.000000     58.000000
#
#               pdays      previous
# count  13564.000000  13564.000000
# mean      41.648555      0.594441
# std      101.985178      1.998193
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# ...

# %% [markdown]
# ## Univariate analysis of train data

# %%
datamap=sns.countplot(df_train["subscribed"],data=df_train)
print(df_train["subscribed"].value_counts())
# Out:
# no     27932
# yes     3715
# Name: subscribed, dtype: int64

# %%
#We can see here that maximum people have not subscribed for the term deposit

# %%
datamap=sns.countplot(df_train['job'],data=df_train)
print(df_train["job"].value_counts())
# Out:
# blue-collar      6842
# management       6639
# technician       5307
# admin.           3631
# services         2903
# retired          1574
# self-employed    1123
# entrepreneur     1008
# unemployed        905
# housemaid         874
# student           635
# unknown           206
# Name: job, dtype: int64

# %%
datamap=sns.countplot(df_train['marital'],data=df_train)
print(df_train["marital"].value_counts())
# Out:
# married     19095
# single       8922
# divorced     3630
# Name: marital, dtype: int64

# %%
datamap=sns.countplot(df_train['education'],data=df_train)
print(df_train["education"].value_counts())
# Out:
# secondary    16224
# tertiary      9301
# primary       4808
# unknown       1314
# Name: education, dtype: int64

# %%
datamap=sns.countplot(df_train['default'],data=df_train)
print(df_train["default"].value_counts())
# Out:
# no     31062
# yes      585
# Name: default, dtype: int64

# %%
datamap=sns.countplot(df_train['housing'],data=df_train)
print(df_train["housing"].value_counts())
# Out:
# yes    17584
# no     14063
# Name: housing, dtype: int64

# %%
datamap=sns.countplot(df_train['loan'],data=df_train)
print(df_train["loan"].value_counts())
# Out:
# no     26516
# yes     5131
# Name: loan, dtype: int64

# %%
datamap=sns.countplot(df_train['contact'],data=df_train)
print(df_train["contact"].value_counts())
# Out:
# cellular     20423
# unknown       9177
# telephone     2047
# Name: contact, dtype: int64

# %%
datamap=sns.countplot(df_train['poutcome'],data=df_train)
print(df_train["poutcome"].value_counts())
# Out:
# unknown    25929
# failure     3362
# other       1288
# success     1068
# Name: poutcome, dtype: int64

# %% [markdown]
# ## Univariate analysis of test data

# %%
datamap=sns.countplot(df_test['job'],data=df_test)
print(df_test["job"].value_counts())
# Out:
# blue-collar      2890
# management       2819
# technician       2290
# admin.           1540
# services         1251
# retired           690
# entrepreneur      479
# self-employed     456
# unemployed        398
# housemaid         366
# student           303
# unknown            82
# Name: job, dtype: int64

# %%
datamap=sns.countplot(df_test['marital'],data=df_test)
print(df_test["marital"].value_counts())
# Out:
# married     8119
# single      3868
# divorced    1577
# Name: marital, dtype: int64

# %%
datamap=sns.countplot(df_test['education'],data=df_test)
print(df_test["education"].value_counts())
# Out:
# secondary    6978
# tertiary     4000
# primary      2043
# unknown       543
# Name: education, dtype: int64

# %%
datamap=sns.countplot(df_test['default'],data=df_test)
print(df_test["default"].value_counts())
# Out:
# no     13334
# yes      230
# Name: default, dtype: int64

# %%
datamap=sns.countplot(df_test['loan'],data=df_test)
print(df_test["loan"].value_counts())
# Out:
# no     11451
# yes     2113
# Name: loan, dtype: int64

# %%
datamap=sns.countplot(df_test['contact'],data=df_test)
print(df_test["contact"].value_counts())
# Out:
# cellular     8862
# unknown      3843
# telephone     859
# Name: contact, dtype: int64

# %%
# Train Data
plt.figure(figsize=(16,10), facecolor='white')
plotnumber=1
for col in train_numerical_col:
    if plotnumber<=7:
        ax=plt.subplot(3,4,plotnumber)   
        sns.distplot(df_train[col],color='m')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
# Test Data
plt.figure(figsize=(16,10), facecolor='white')
plotnumber=1
for col in test_numerical_col:
    if plotnumber<=7:
        ax=plt.subplot(3,4,plotnumber)   
        sns.distplot(df_test[col],color='m')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.title("Comparision between age and subscribed")
sns.stripplot(x="subscribed",y="age",data=df_train)
plt.show()

# %%
plt.title("Comparision between balance and subscribed")
sns.lineplot(x="subscribed",y="balance",data=df_train)
plt.show()

# %%
plt.title("Comparision between day and subscribed")
sns.stripplot(x="subscribed",y="day",data=df_train)
plt.show()

# %%
plt.title("Comparision between duration and subscribed")
sns.lineplot(x="subscribed",y="duration",data=df_train)
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(df_train,hue="subscribed",palette="Dark2")
plt.show()

# %% [markdown]
# ## Checking the outliers

# %%
#By plotting boxplot

plt.figure(figsize=(10,6),facecolor='white')
plotnumber=1
for col in train_numerical_col:
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df_train[col],palette='bright')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# We can see outliers in all the numerical columns except day

# %%
#Removing outliers by z score

from scipy.stats import zscore
out_features=df_train[['age','balance','duration','campaign','pdays','previous']]
z=np.abs(zscore(out_features))  
z
# Out:
#             age   balance  duration  campaign     pdays  previous
# 0      1.415793  0.187933  0.832754  0.245906  0.408555  0.237059
# 1      0.937156  0.449397  0.649957  0.245906  0.408555  0.237059
# 2      1.313627  0.156159  0.070449  0.567059  0.408555  0.237059
# 3      1.509911  0.635055  2.368149  0.567059  0.447299  1.001336
# 4      0.937156  0.411091  0.474054  0.567059  0.408555  0.237059
# ...         ...       ...       ...       ...       ...       ...
# 31642  1.125392  0.450388  0.552724  0.245906  0.408555  0.237059
# 31643  1.133439  0.324903  0.699635  0.245906  0.408555  0.237059
# 31644  0.843038  0.347358  0.859979  0.075247  0.408555  0.237059
# 31645  1.509911  0.376088  0.918319  1.359859  2.994723  4.716521
# 31646  1.321675  0.383022  6.669728  0.245906  0.408555  0.237059
#
# [31647 rows x 6 columns]

# %%
#threshold=3

np.where(z>3)
# Out:
# (array([   21,    26,    36, ..., 31622, 31645, 31646], dtype=int64),
#  array([3, 1, 4, ..., 4, 5, 2], dtype=int64))

# %%
df1_train=df_train[(z<3).all(axis=1)]  
df1_train
# Out:
#        age         job   marital  education default  balance housing loan  \
# 0       56      admin.   married    unknown      no     1933      no   no
# 1       31     unknown   married  secondary      no        3      no   no
# 2       27    services   married  secondary      no      891     yes   no
# 3       57  management  divorced   tertiary      no     3287      no   no
# 4       31  technician   married  secondary      no      119     yes   no
# ...    ...         ...       ...        ...     ...      ...     ...  ...
# 31640   43  management    single  secondary      no     2968      no   no
# 31641   37  technician    single   tertiary      no     1309      no   no
# 31642   29  management    single   tertiary      no        0     yes   no
# 31643   53  management  divorced   tertiary      no      380      no  yes
# 31644   32  management    single   tertiary      no      312      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
print("Old dataframe",df_train.shape[0])  #df.shape[0] will give only the rows
print("New dataframe",df1_train.shape[0])
# Out:
# Old dataframe 31647
# New dataframe 28124

# %%
#Checking the data loss percentage after removing the outliers

print("Data Loss Percentage:", ((df_train.shape[0]-df1_train.shape[0])/df_train.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 11.132176825607482

# %%
#Now lets check with IQR method:

#1st Quantile
Q1=out_features.quantile(0.25)

#3rd Quantile
Q3=out_features.quantile(0.75)

IQR=Q3-Q1

df2_train=df_train[~((df_train < (Q1-1.5*IQR))|(df_train> (Q3+ 1.5*IQR))).any(axis=1)]

# %%
print("Data Loss Percentage:", ((df_train.shape[0]-df2_train.shape[0])/df_train.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 37.437987802951305

# %%
#We will choose z score method as its giving less data loss comparatively.

# %%
df_train=df1_train

# %%
df_train
# Out:
#        age         job   marital  education default  balance housing loan  \
# 0       56      admin.   married    unknown      no     1933      no   no
# 1       31     unknown   married  secondary      no        3      no   no
# 2       27    services   married  secondary      no      891     yes   no
# 3       57  management  divorced   tertiary      no     3287      no   no
# 4       31  technician   married  secondary      no      119     yes   no
# ...    ...         ...       ...        ...     ...      ...     ...  ...
# 31640   43  management    single  secondary      no     2968      no   no
# 31641   37  technician    single   tertiary      no     1309      no   no
# 31642   29  management    single   tertiary      no        0     yes   no
# 31643   53  management  divorced   tertiary      no      380      no  yes
# 31644   32  management    single   tertiary      no      312      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
#By plotting boxplot TEST Column

plt.figure(figsize=(10,6),facecolor='white')
plotnumber=1
for col in test_numerical_col:
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df_test[col],palette='bright')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
#We can see outliers in all the numerical columns except day

# %%
#Removing outliers by z score

from scipy.stats import zscore
out_features=df_test[['age','balance','duration','campaign','pdays','previous']]
z=np.abs(zscore(out_features))

# %%
#threshold=3

np.where(z>3)
# Out:
# (array([    1,     9,    14, ..., 13550, 13555, 13563], dtype=int64),
#  array([0, 4, 1, ..., 2, 3, 4], dtype=int64))

# %%
df1_test=df_test[(z<3).all(axis=1)]  
df1_test
# Out:
#        age            job   marital  education default  balance housing loan  \
# 0       32       services   married  secondary      no      118     yes   no
# 2       31  self-employed    single   tertiary      no      144     yes   no
# 3       57       services    single    primary      no     3777     yes   no
# 4       45    blue-collar  divorced  secondary      no     -705      no  yes
# 5       32     management    single   tertiary      no        0     yes   no
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 13558   32     technician    single  secondary      no      129     yes   no
# 13559   39     management   married   tertiary      no       45      no   no
# 13560   54    blue-collar   married    primary      no     2281     yes   no
# 13561   35        retired   married    primary      no      285     yes   no
# 13562   29         admin.    single  secondary      no      464      no   no
#
# ...

# %%
print("Old dataframe",df_test.shape[0])  #df.shape[0] will give only the rows
print("New dataframe",df1_test.shape[0])
# Out:
# Old dataframe 13564
# New dataframe 12034

# %%
#Checking the data loss percentage after removing the outliers

print("Data Loss Percentage:", ((df_test.shape[0]-df1_test.shape[0])/df_test.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 11.279858448835151

# %%
#Now lets check with IQR method:

#1st Quantile
Q1=out_features.quantile(0.25)

#3rd Quantile
Q3=out_features.quantile(0.75)

IQR=Q3-Q1

df2_test=df_test[~((df_test < (Q1-1.5*IQR))|(df_test> (Q3+ 1.5*IQR))).any(axis=1)]

# %%
print("Data Loss Percentage:", ((df_test.shape[0]-df2_test.shape[0])/df_test.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 38.24093187850192

# %%
df_test=df1_test

# %%
df_test
# Out:
#        age            job   marital  education default  balance housing loan  \
# 0       32       services   married  secondary      no      118     yes   no
# 2       31  self-employed    single   tertiary      no      144     yes   no
# 3       57       services    single    primary      no     3777     yes   no
# 4       45    blue-collar  divorced  secondary      no     -705      no  yes
# 5       32     management    single   tertiary      no        0     yes   no
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 13558   32     technician    single  secondary      no      129     yes   no
# 13559   39     management   married   tertiary      no       45      no   no
# 13560   54    blue-collar   married    primary      no     2281     yes   no
# 13561   35        retired   married    primary      no      285     yes   no
# 13562   29         admin.    single  secondary      no      464      no   no
#
# ...

# %% [markdown]
# ## Checking for skewness

# %%
df_train.skew()
# Out:
# age         0.438496
# balance     2.437605
# day         0.073752
# duration    1.596552
# campaign    2.059359
# pdays       2.824483
# previous    3.691573
# dtype: float64

# %%
#Removing skewness
df_train['balance']=np.cbrt(df_train['balance'])
df_train['duration']=np.cbrt(df_train['duration'])
df_train['campaign']=np.log(df_train['campaign'])
df_train['pdays']=np.sqrt(df_train['pdays'])
df_train['previous']=np.cbrt(df_train['previous'])

# %%
df_train.skew()
# Out:
# age         0.438496
# balance    -0.435065
# day         0.073752
# duration    0.310493
# campaign    0.596930
# pdays      -0.692858
# previous    2.299676
# dtype: float64

# %%
#All the skewness is reduced except in previous

# %%
#Lets visualize data after removing skewness

plt.figure(figsize=(16,10), facecolor='white')
plotnumber=1
for col in train_numerical_col:
    if plotnumber<=7:
        ax=plt.subplot(3,4,plotnumber)   
        sns.distplot(df_train[col],color='m')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
# Skewness for TEST data/

# %%
df_test.skew()
# Out:
# age         0.435270
# balance     2.476671
# day         0.100926
# duration    1.578135
# campaign    1.958366
# pdays       2.728161
# previous    3.398894
# dtype: float64

# %%
#Removing skewness
df_test['balance']=np.cbrt(df_test['balance'])
df_test['duration']=np.cbrt(df_test['duration'])
df_test['campaign']=np.log(df_test['campaign'])
df_test['pdays']=np.sqrt(df_test['pdays'])
df_test['previous']=np.cbrt(df_test['previous'])

# %%
df_test.skew()
# Out:
# age         0.435270
# balance    -0.412190
# day         0.100926
# duration    0.290029
# campaign    0.577525
# pdays      -0.663886
# previous    2.198396
# dtype: float64

# %%
#Lets visualize data after removing skewness

plt.figure(figsize=(16,10), facecolor='white')
plotnumber=1
for col in test_numerical_col:
    if plotnumber<=7:
        ax=plt.subplot(3,4,plotnumber)   
        sns.distplot(df_test[col],color='m')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ## Encoding Categorical columns

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df_train.columns:
    if df_train[i].dtypes=='object':
        df_train[i]=OE.fit_transform(df_train[i].values.reshape(-1,1)) 
        
df_train
# Out:
#        age   job  marital  education  default    balance  housing  loan  \
# 0       56   0.0      1.0        3.0      0.0  12.456918      0.0   0.0
# 1       31  11.0      1.0        1.0      0.0   1.442250      0.0   0.0
# 2       27   7.0      1.0        1.0      0.0   9.622603      1.0   0.0
# 3       57   4.0      0.0        2.0      0.0  14.868480      0.0   0.0
# 4       31   9.0      1.0        1.0      0.0   4.918685      1.0   0.0
# ...    ...   ...      ...        ...      ...        ...      ...   ...
# 31640   43   4.0      2.0        1.0      0.0  14.371032      0.0   0.0
# 31641   37   9.0      2.0        2.0      0.0  10.939057      0.0   0.0
# 31642   29   4.0      2.0        2.0      0.0   0.000000      1.0   0.0
# 31643   53   4.0      0.0        2.0      0.0   7.243156      0.0   1.0
# 31644   32   4.0      2.0        2.0      0.0   6.782423      0.0   0.0
#
#        contact  day  month  duration  campaign     pdays  previous  poutcome  \
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df_test.columns:
    if df_test[i].dtypes=='object':
        df_test[i]=OE.fit_transform(df_test[i].values.reshape(-1,1)) 
        
df_test
# Out:
#        age  job  marital  education  default    balance  housing  loan  \
# 0       32  7.0      1.0        1.0      0.0   4.904868      1.0   0.0
# 2       31  6.0      2.0        2.0      0.0   5.241483      1.0   0.0
# 3       57  7.0      2.0        0.0      0.0  15.573360      1.0   0.0
# 4       45  1.0      0.0        1.0      0.0  -8.900130      0.0   1.0
# 5       32  4.0      2.0        2.0      0.0   0.000000      1.0   0.0
# ...    ...  ...      ...        ...      ...        ...      ...   ...
# 13558   32  9.0      2.0        1.0      0.0   5.052774      1.0   0.0
# 13559   39  4.0      1.0        2.0      0.0   3.556893      0.0   0.0
# 13560   54  1.0      1.0        0.0      0.0  13.163613      1.0   0.0
# 13561   35  5.0      1.0        0.0      0.0   6.580844      1.0   0.0
# 13562   29  0.0      2.0        1.0      0.0   7.741753      0.0   0.0
#
#        contact  day  month  duration  campaign     pdays  previous  poutcome
# ...

# %%
df_train.info()   #no object data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28124 entries, 0 to 31644
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         28124 non-null  int64
#  1   job         28124 non-null  float64
#  2   marital     28124 non-null  float64
#  3   education   28124 non-null  float64
#  4   default     28124 non-null  float64
#  5   balance     28124 non-null  float64
#  6   housing     28124 non-null  float64
#  7   loan        28124 non-null  float64
#  8   contact     28124 non-null  float64
#  9   day         28124 non-null  int64
#  10  month       28124 non-null  float64
#  11  duration    28124 non-null  float64
#  12  campaign    28124 non-null  float64
#  13  pdays       3927 non-null   float64
#  14  previous    28124 non-null  float64
#  15  poutcome    28124 non-null  float64
#  16  subscribed  28124 non-null  float64
# dtypes: float64(15), int64(2)
# memory usage: 3.9 MB

# %%
df_train.describe()  #count of all the values is same i.e. there are no null values
# Out:
#                 age           job       marital     education       default  \
# count  28124.000000  28124.000000  28124.000000  28124.000000  28124.000000
# mean      40.650192      4.346146      1.167722      1.225039      0.019201
# std       10.080098      3.288341      0.605709      0.746758      0.137232
# min       18.000000      0.000000      0.000000      0.000000      0.000000
# 25%       33.000000      1.000000      1.000000      1.000000      0.000000
# 50%       39.000000      4.000000      1.000000      1.000000      0.000000
# 75%       48.000000      7.000000      2.000000      2.000000      0.000000
# max       72.000000     11.000000      2.000000      3.000000      1.000000
#
#             balance       housing          loan       contact           day  \
# count  28124.000000  28124.000000  28124.000000  28124.000000  28124.000000
# mean       7.141730      0.550633      0.166797      0.671455     15.855177
# ...

# %% [markdown]
# ## Correlation between target variable and independent variables

# %%
cor=df_train.corr()    #-1 represents highly negative correlation and +1 is highly positive correlation
cor
# Out:
#                  age       job   marital  education   default   balance  \
# age         1.000000 -0.030552 -0.411087  -0.100363 -0.009616  0.079543
# job        -0.030552  1.000000  0.067076   0.169526 -0.007400  0.026094
# marital    -0.411087  0.067076  1.000000   0.109940 -0.012221  0.034716
# education  -0.100363  0.169526  0.109940   1.000000 -0.007467  0.064140
# default    -0.009616 -0.007400 -0.012221  -0.007467  1.000000 -0.209161
# balance     0.079543  0.026094  0.034716   0.064140 -0.209161  1.000000
# housing    -0.155557 -0.122764 -0.026593  -0.096581 -0.014763 -0.070652
# loan        0.005488 -0.038629 -0.045159  -0.047982  0.081270 -0.140556
# contact     0.029036 -0.084375 -0.042070  -0.121975  0.014592 -0.055374
# day        -0.009937  0.020514 -0.008386   0.017677  0.007138 -0.013262
# month      -0.042070 -0.088359 -0.003321  -0.056416  0.007290 -0.004558
# duration   -0.031297 -0.003418  0.016357   0.002066 -0.000054  0.024577
# ...

# %%
#We can visualize this by plotting a heatmap

plt.figure(figsize=(20,20))
sns.heatmap(df_train.corr(),linewidths=0.1,fmt=".1g",linecolor="black",annot=True,cmap="Blues_r")   
plt.yticks(rotation=0)
plt.show()

# %%
#We can see high negative correlation between previous and poutcome

# %%
df_train.corr()["subscribed"].sort_values(ascending=False)   #arrange the correlation in descending order
# Out:
# subscribed    1.000000
# duration      0.328075
# previous      0.189480
# balance       0.094746
# education     0.075838
# marital       0.056387
# job           0.036743
# age          -0.007172
# default      -0.014500
# month        -0.022564
# day          -0.030122
# loan         -0.074803
# campaign     -0.082773
# poutcome     -0.091071
# housing      -0.145640
# contact      -0.158031
# pdays        -0.190749
# Name: subscribed, dtype: float64

# %% [markdown]
# ## Visualizing the correlation between the label and other features using bar plot

# %%
plt.figure(figsize=(22,7))
df_train.corr()["subscribed"].sort_values(ascending=False).drop(["subscribed"]).plot(kind='bar',color='m')   
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title("Correlation between Target and features using bar plot")
plt.show()

# %%
#We can see that all the features are moderately corelated to the target
##Also the age has very less correlation with the target variable so if we want we can drop it

# %% [markdown]
# ## Seperating Features(independent variables) and Label(Dependent or Target variable)

# %%
#For train dataset:

x=df_train.drop("subscribed",axis=1)
y=df_train['subscribed']

# %%
x
# Out:
#        age   job  marital  education  default    balance  housing  loan  \
# 0       56   0.0      1.0        3.0      0.0  12.456918      0.0   0.0
# 1       31  11.0      1.0        1.0      0.0   1.442250      0.0   0.0
# 2       27   7.0      1.0        1.0      0.0   9.622603      1.0   0.0
# 3       57   4.0      0.0        2.0      0.0  14.868480      0.0   0.0
# 4       31   9.0      1.0        1.0      0.0   4.918685      1.0   0.0
# ...    ...   ...      ...        ...      ...        ...      ...   ...
# 31640   43   4.0      2.0        1.0      0.0  14.371032      0.0   0.0
# 31641   37   9.0      2.0        2.0      0.0  10.939057      0.0   0.0
# 31642   29   4.0      2.0        2.0      0.0   0.000000      1.0   0.0
# 31643   53   4.0      0.0        2.0      0.0   7.243156      0.0   1.0
# 31644   32   4.0      2.0        2.0      0.0   6.782423      0.0   0.0
#
#        contact  day  month  duration  campaign     pdays  previous  poutcome
# ...

# %%
y
# Out:
# 0        0.0
# 1        0.0
# 2        0.0
# 3        1.0
# 4        0.0
#         ...
# 31640    0.0
# 31641    0.0
# 31642    0.0
# 31643    1.0
# 31644    0.0
# Name: subscribed, Length: 28124, dtype: float64

# %%
df_train.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# balance           0
# housing           0
# loan              0
# contact           0
# day               0
# month             0
# duration          0
# campaign          0
# pdays         24197
# previous          0
# poutcome          0
# subscribed        0
# dtype: int64

# %%
#Dropping pdays as it has almost all the null values

x.drop(['pdays'],axis=1,inplace=True)

# %% [markdown]
# ## Feature scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train1=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)  
x
# Out:
#        age   job  marital  education  default    balance  housing  loan  \
# 0       56   0.0      1.0        3.0      0.0  12.456918      0.0   0.0
# 1       31  11.0      1.0        1.0      0.0   1.442250      0.0   0.0
# 2       27   7.0      1.0        1.0      0.0   9.622603      1.0   0.0
# 3       57   4.0      0.0        2.0      0.0  14.868480      0.0   0.0
# 4       31   9.0      1.0        1.0      0.0   4.918685      1.0   0.0
# ...    ...   ...      ...        ...      ...        ...      ...   ...
# 31640   43   4.0      2.0        1.0      0.0  14.371032      0.0   0.0
# 31641   37   9.0      2.0        2.0      0.0  10.939057      0.0   0.0
# 31642   29   4.0      2.0        2.0      0.0   0.000000      1.0   0.0
# 31643   53   4.0      0.0        2.0      0.0   7.243156      0.0   1.0
# 31644   32   4.0      2.0        2.0      0.0   6.782423      0.0   0.0
#
#        contact  day  month  duration  campaign  previous  poutcome
# ...

# %% [markdown]
# ## Checking Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF values   Features
# 0    16.386909        age
# 1     2.844781        job
# 2     5.147548    marital
# 3     3.852300  education
# 4     1.070148    default
# 5     2.534754    balance
# 6     2.459785    housing
# 7     1.228495       loan
# 8     2.046310    contact
# 9     4.555190        day
# 10    5.529649      month
# 11   13.459984   duration
# 12    2.158008   campaign
# 13    3.998000   previous
# 14   30.935539   poutcome

# %%
#We can see very high vif in poutcome

# %%
#Dropping poutcome data

x.drop(["poutcome"],axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF values   Features
# 0    11.136299        age
# 1     2.811439        job
# 2     4.457166    marital
# 3     3.743752  education
# 4     1.069410    default
# 5     2.529360    balance
# 6     2.438547    housing
# 7     1.226782       loan
# 8     2.041381    contact
# 9     4.435924        day
# 10    5.384042      month
# 11   11.370923   duration
# 12    2.112107   campaign
# 13    1.274109   previous

# %%
#Still can see high vif in duration

# %%
#Dropping duration data

x.drop(["duration"],axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF values   Features
# 0     8.282907        age
# 1     2.792158        job
# 2     4.043827    marital
# 3     3.690816  education
# 4     1.068400    default
# 5     2.518608    balance
# 6     2.385342    housing
# 7     1.224604       loan
# 8     2.040267    contact
# 9     4.392680        day
# 10    5.316405      month
# 11    2.112030   campaign
# 12    1.273198   previous

# %%
y.value_counts()
# Out:
# 0.0    25264
# 1.0     2860
# Name: subscribed, dtype: int64

# %% [markdown]
# ## Oversampling

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x,y=SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0.0    25264
# 1.0    25264
# Name: subscribed, dtype: int64

# %%
#Now the data is balanced by the ratio of 1:1 ...now we can build machine learning Classification model

# %% [markdown]
# ## Modelling

# %%
#Importing necessary libraries

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    RFR=RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is",maxAccu,"at random_state",maxRS)
# Out:
# Best accuracy is 0.9515139521076588 at random_state 69

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %% [markdown]
# ## Classification Algorithms

# %%
#Importing all the classification libraries

from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
#Checking accuracy for Random Forest Classifier

RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC=RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.9503265386898871
# [[7432  209]
#  [ 544 6974]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.97      0.95      7641
#          1.0       0.97      0.93      0.95      7518
#
#     accuracy                           0.95     15159
#    macro avg       0.95      0.95      0.95     15159
# weighted avg       0.95      0.95      0.95     15159

# %%
#Checking accuracy for logistic regression model

LR=LogisticRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.7053235701563427
# [[5248 2393]
#  [2074 5444]]
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.69      0.70      7641
#          1.0       0.69      0.72      0.71      7518
#
#     accuracy                           0.71     15159
#    macro avg       0.71      0.71      0.71     15159
# weighted avg       0.71      0.71      0.71     15159

# %%
#Checking accuracy for support vector machine classifier

svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.7125140180750709
# [[5123 2518]
#  [1840 5678]]
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.67      0.70      7641
#          1.0       0.69      0.76      0.72      7518
#
#     accuracy                           0.71     15159
#    macro avg       0.71      0.71      0.71     15159
# weighted avg       0.71      0.71      0.71     15159

# %%
#Checking accuracy for Gradient Boosting Classifier

GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB=GB.predict(x_test)
print(accuracy_score(y_test,predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.9276337489280295
# [[7383  258]
#  [ 839 6679]]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.97      0.93      7641
#          1.0       0.96      0.89      0.92      7518
#
#     accuracy                           0.93     15159
#    macro avg       0.93      0.93      0.93     15159
# weighted avg       0.93      0.93      0.93     15159

# %%
#Checking accuracy for Ada Boost Classifier

ABC=AdaBoostClassifier()
ABC.fit(x_train,y_train)
predABC=ABC.predict(x_test)
print(accuracy_score(y_test,predABC))
print(confusion_matrix(y_test,predABC))
print(classification_report(y_test,predABC))
# Out:
# 0.9150999406293291
# [[7292  349]
#  [ 938 6580]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.95      0.92      7641
#          1.0       0.95      0.88      0.91      7518
#
#     accuracy                           0.92     15159
#    macro avg       0.92      0.91      0.91     15159
# weighted avg       0.92      0.92      0.91     15159

# %%
#Checking accuracy for Bagging Classifier

BC=BaggingClassifier()
BC.fit(x_train,y_train)
predBC=BC.predict(x_test)
print(accuracy_score(y_test,predBC))
print(confusion_matrix(y_test,predBC))
print(classification_report(y_test,predBC))
# Out:
# 0.9383204696879741
# [[7356  285]
#  [ 650 6868]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.96      0.94      7641
#          1.0       0.96      0.91      0.94      7518
#
#     accuracy                           0.94     15159
#    macro avg       0.94      0.94      0.94     15159
# weighted avg       0.94      0.94      0.94     15159

# %%
#Checking accuracy for ExtraTrees Classifier

ET=ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET=ET.predict(x_test)
print(accuracy_score(y_test,predET))
print(confusion_matrix(y_test,predET))
print(classification_report(y_test,predET))
# Out:
# 0.9555379642456626
# [[7385  256]
#  [ 418 7100]]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.97      0.96      7641
#          1.0       0.97      0.94      0.95      7518
#
#     accuracy                           0.96     15159
#    macro avg       0.96      0.96      0.96     15159
# weighted avg       0.96      0.96      0.96     15159

# %% [markdown]
# ## Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
#Checking cv score for Random Forest Classifier

score=cross_val_score(RFC,x,y) 
print(score)  #this will print the score 5 times one for each fold
print(score.mean())   #will takeout the mean for all those 5 scores
print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predRFC)-score.mean())
# Out:
# [0.75944983 0.98327726 0.98426677 0.98218704 0.98119743]
# 0.9380756656335472
# Difference between Accuracy score and Cross validation score is: 0.012250873056339984

# %%
#Checking cv score for Logistic Regression

score=cross_val_score(LR,x,y)  
print(score)
print(score.mean())   
print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predLR)-score.mean())
# Out:
# [0.69631902 0.70690679 0.70779735 0.71162791 0.70549233]
# 0.7056286784135664
# Difference between Accuracy score and Cross validation score is: -0.00030510825722362966

# %%
#Checking cv score for Gradient Boosting Classifier

score=cross_val_score(GB,x,y)  
print(score)
print(score.mean())   
print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predGB)-score.mean())
# Out:
# [0.73342569 0.96507026 0.96447655 0.96585849 0.95982187]
# 0.9177305695696866
# Difference between Accuracy score and Cross validation score is: 0.00990317935834295

# %%
#Checking cv score for Support Vector Machine Classifier

score=cross_val_score(svc,x,y)  
print(score)
print(score.mean())   
print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predsvc)-score.mean())
# Out:
# [0.70740154 0.71353651 0.71591134 0.72073231 0.71608115]
# 0.7147325710163999
# Difference between Accuracy score and Cross validation score is: -0.0022185529413289995

# %%
#Checking cv score for Ada Boosting Classifier

score=cross_val_score(ABC,x,y)  
print(score)
print(score.mean())   
print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predABC)-score.mean())
# Out:
# [0.74440926 0.94409262 0.94241045 0.93854527 0.94250371]
# 0.9023922629919978
# Difference between Accuracy score and Cross validation score is: 0.012707677637331272

# %%
#Checking cv score for Bagging Classifier

score=cross_val_score(BC,x,y)  
print(score)
print(score.mean())   
print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predBC)-score.mean())
# Out:
# [0.74025331 0.97377795 0.97437166 0.97615042 0.97446809]
# 0.9278042869286699
# Difference between Accuracy score and Cross validation score is: 0.010516182759304216

# %%
#Checking cv score for Extra Trees Classifier

score=cross_val_score(ET,x,y)  
print(score)
print(score.mean())   

print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predET)-score.mean())
# Out:
# [0.83514744 0.98011083 0.98011083 0.97971301 0.9805047 ]
# 0.951117360334732
# Difference between Accuracy score and Cross validation score is: 0.004420603910930576

# %%
##Here we can see svc has the lowest difference but its accuracy % is quite low so we will go ahead with extra trees classifier

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
# !pip install sklearn.model

# %%
#Extra Trees Classifier

from sklearn.model_selection import GridSearchCV

parameters={'criterion':['gini','entropy'],
           'random_state': [10,50,1000],
           'max_depth':[0,10,20],
           'n_jobs':[-2,-1,1],
           'n_estimators':[50,100,200,300]}

# %%
GCV=GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 10, 20],
#                          'n_estimators': [50, 100, 200, 300],
#                          'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 1000]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 20,
#  'n_estimators': 200,
#  'n_jobs': -2,
#  'random_state': 50}

# %%
Final_model=ExtraTreesClassifier(criterion='gini',max_depth=20,n_estimators=200,n_jobs=-2,random_state=50)
Final_model.fit(x_train,y_train)
pred=Final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 92.76337489280296

# %% [markdown]
# # Saving the model

# %%
#Saving the model using .pkl

import joblib
joblib.dump(Final_model,"Bank Marketing.pkl")
# Out:
# ['Bank Marketing.pkl']

# %%
#Lets load the saved model and get the predictions

model=joblib.load("Bank Marketing.pkl")


#Prediction
prediction=model.predict(x_test)
prediction
# Out:
# array([1., 0., 0., ..., 1., 0., 1.])

# %% [markdown]
# ## Plot the AUC ROC curve

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
y_pred_prob=Final_model.predict_proba(x_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
roc_auc=auc(fpr,tpr)

plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label="RandomForestClassifier(area=%0.2f)"% roc_auc)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()
auc_score=roc_auc_score(y_test,Final_model.predict(x_test))
print("AUC score:","\n",auc_score)
# Out:
# AUC score:
#  0.9274978371500077
